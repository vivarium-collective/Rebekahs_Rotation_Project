# %%
import cobra
from cobra.io import read_sbml_model
from pprint import pprint
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from cobra.medium import minimal_medium

from process_bigraph import Composite
from process_bigraph import ProcessTypes
from process_bigraph.emitter import gather_emitter_results

from cdFBA import register_types
from cdFBA.processes.dfba import dFBA, UpdateEnvironment, StaticConcentration, Injector, WaveFunction

from cdFBA.utils import make_cdfba_composite, get_injector_spec, get_wave_spec, get_static_spec, set_concentration, set_kinetics, get_exchanges

from in_silico_functions.carbon_sources import (load, met_info, find_fluxes, make_fluxes_dict, make_dict,main, classify_met)

# %%
def get_mini_medium(model, target_growth=10e-4):
    ## make a copy of the model
    try_model = model.copy()

    ## compute the minimum media neccessary for growth at targeted_growth
    mini_growth = minimal_medium(try_model, target_growth, minimize_components=10, open_exchanges=True)

    ## set minimal medium
    mini_medium = {}
    for i in mini_growth.index:
        mini_medium[i] = try_model.medium[i]

    ## get all other metabolites that can be added to the medium
    additional_medium = try_model.medium
    for i in mini_medium.keys():
        del additional_medium[i]
    return mini_medium, additional_medium

# %%
# Load models

gut_models = {
        "B_thetaiotaomicron": "/Users/rebekahsheih/PycharmProjects/Rebekahs_Rotation_Project/Vivarium/cdFBA-main/Notebooks/sbml_mini/Bacteroides_thetaiotaomicron_VPI_5482.xml",
        "E_rectale": "/Users/rebekahsheih/PycharmProjects/Rebekahs_Rotation_Project/Vivarium/cdFBA-main/Notebooks/sbml_mini/Eubacterium_rectale_ATCC_33656.xml"
    }

models = {k: read_sbml_model(v) for k, v in gut_models.items()}

BT = models["B_thetaiotaomicron"]
ER = models["E_rectale"]

# %%
# Create minimal media
medium_bt = get_mini_medium(BT)[0]
medium_bt["EX_MGlcn175_rl(e)"] = 0.00
medium_bt["EX_cholate(e)"] = 0.00 # want bt to consume cholate and produce acetate for er to eat, give it nothing so that it has to get it from shared environment
# medium_bt["EX_hspg(e)"] = 0.00  # kill switch for bt

BT.medium = medium_bt

medium_er = get_mini_medium(ER)[0]
medium_er["EX_pullulan1200(e)"] = 10e-6 # if this number is small enough, er produces more butyrate
medium_er["EX_ac(e)"] = 0 # want ER to consume acetate from bt, so don't give it acetate so that it has to get it from bt
# I am seeing that organism consumes acetate and pullulan together, but does not consume acetate unless there is enough pullulan in media.
# w/o acetate, uses more pullulan1200, w/acetate, consumes both
ER.medium = medium_er

# %%
# write minimal media files, view media
cobra.io.write_sbml_model(BT, "/in_silico_scripts/sbml_mini/bt.xml")
bt_try = read_sbml_model("/in_silico_scripts/sbml_mini/bt.xml")
bt_try.optimize()
print(bt_try.summary())

cobra.io.write_sbml_model(ER, "/in_silico_scripts/sbml_mini/er.xml")
er_try = read_sbml_model("/in_silico_scripts/sbml_mini/er.xml")
er_try.optimize()
print(er_try.summary())
# Out:
# Objective
# =========
# 1.0 biomass345 = 0.0
#
# Uptake
# ------
# Empty DataFrame
# Columns: [Metabolite, Reaction, Flux, C-Number, C-Flux]
# Index: []
#
# Secretion
# ---------
# Empty DataFrame
# Columns: [Metabolite, Reaction, Flux, C-Number, C-Flux]
# Index: []
#
# Objective
# =========
# 1.0 biomass205 = 0.0006087523917212463
#
# Uptake
# ------
#      Metabolite           Reaction      Flux  C-Number C-Flux
#      Lcystin[e]      EX_Lcystin(e) 2.459E-05         6  0.17%
#       alagln[e]       EX_alagln(e) 0.0006265         8  5.64%
#       alahis[e]       EX_alahis(e) 4.989E-05         9  0.51%
#       alathr[e]       EX_alathr(e)  0.000329         7  2.59%
#          ca2[e]          EX_ca2(e) 4.833E-06         0  0.00%
#           cl[e]           EX_cl(e) 4.833E-06         0  0.00%
#      cobalt2[e]      EX_cobalt2(e) 4.833E-06         0  0.00%
#          cu2[e]          EX_cu2(e) 4.833E-06         0  0.00%
#          fe2[e]          EX_fe2(e)  1.45E-05         0  0.00%
#          fe3[e]          EX_fe3(e) 4.833E-06         0  0.00%
#          fol[e]          EX_fol(e)  1.45E-05        19  0.31%
#       glyasn[e]       EX_glyasn(e)  9.03E-05         6  0.61%
#       glyc3p[e]       EX_glyc3p(e) 0.0007562         3  2.55%
#       glyleu[e]       EX_glyleu(e) 0.0002621         8  2.36%
#       glyphe[e]       EX_glyphe(e) 0.0001073        11  1.33%
#       glytyr[e]       EX_glytyr(e) 7.243E-05        11  0.90%
#         hxan[e]         EX_hxan(e) 9.211E-05         5  0.52%
#            k[e]            EX_k(e) 4.833E-06         0  0.00%
#       metala[e]       EX_metala(e) 7.393E-05         8  0.67%
#          mg2[e]          EX_mg2(e) 4.833E-06         0  0.00%
#          mn2[e]          EX_mn2(e) 4.833E-06         0  0.00%
# pullulan1200[e] EX_pullulan1200(e) 1.001E-05      7200 81.07%
#      rbflvrd[e]      EX_rbflvrd(e) 2.459E-05        17  0.47%
#          so4[e]          EX_so4(e) 4.833E-06         0  0.00%
#         spmd[e]         EX_spmd(e) 4.833E-06         7  0.04%
#          ura[e]          EX_ura(e) 4.944E-05         4  0.22%
#          zn2[e]          EX_zn2(e) 4.833E-06         0  0.00%
#       dnarep[c]       dreplication 0.0006088         0  0.00%
# proteinsynth[c]      pbiosynthesis 0.0006088         0  0.00%
#     rnatrans[c]     rtranscription 0.0006088         0  0.00%
#        gthrd[c]      sink_gthrd(c) 4.833E-06        10  0.05%
#
# Secretion
# ---------
# Metabolite      Reaction       Flux  C-Number C-Flux
#    4hba[c]       DM_4HBA -4.833E-06         7  0.05%
#   5drib[c]      DM_5DRIB -9.667E-06         5  0.07%
#   dhptd[c]   DM_dhptd(c)   -2.9E-05         5  0.22%
#   ala_L[e]   EX_ala_L(e) -6.066E-05         3  0.28%
# biomass[c] EX_biomass(e) -0.0006088         0  0.00%
#     but[e]     EX_but(e)  -0.007653         4 46.28%
#     co2[e]     EX_co2(e)  -0.002625         1  3.97%
#     for[e]     EX_for(e)  -0.008241         1 12.46%
#     gly[e]     EX_gly(e)  -9.73E-05         2  0.29%
#       h[e]       EX_h(e)   -0.02683         0  0.00%
#  ribflv[e]  EX_ribflv(e) -1.492E-05        17  0.38%
#    succ[e]    EX_succ(e)  -0.005951         4 35.99%

# %%
gut_models_mini = {
        "B_thetaiotaomicron": "/Users/rebekahsheih/PycharmProjects/Rebekahs_Rotation_Project/in_silico_scripts/sbml_mini/bt.xml",
        "E_rectale": "/Users/rebekahsheih/PycharmProjects/Rebekahs_Rotation_Project/in_silico_scripts/sbml_mini/er.xml"
    }

models = {k: read_sbml_model(v) for k, v in gut_models_mini.items()}

# %%
exchanges = ['EX_ac(e)', 'EX_but(e)', 'EX_ch4(e)','EX_cholate(e)', 'EX_pullulan1200(e)'] # acetate, butyrate, H2, methane, cholate, pullulan

volume = 2

# dFBA model
spec = make_cdfba_composite(gut_models_mini, medium_type=None, exchanges=exchanges, volume=volume, interval=0.1)

pprint(spec)
# Out:
# {'Shared Environment': {'concentrations': {'B_thetaiotaomicron': 0.25,
#                                            'Cholate': 10.0,
#                                            'E_rectale': 0.25,
#                                            'acetate': 10.0,
#                                            'butyrate': 10.0,
#                                            'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': 10.0},
#                         'counts': {'B_thetaiotaomicron': 0.5,
#                                    'Cholate': 20,
#                                    'E_rectale': 0.5,
#                                    'acetate': 20,
#                                    'butyrate': 20,
#                                    'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': 20},
#                         'volume': 2},
#  'Species': {'B_thetaiotaomicron': {'_type': 'process',
#                                     'address': 'local:dFBA',
#                                     'config': {'bounds': {},
#                                                'changes': {'bounds': {},
#                                                            'gene_knockout': [],
#                                                            'kinetics': {},
#                                                            'reaction_knockout': []},
#                                                'kinetics': {'Cholate': (0.5,
#                                                                         2.0),
#                                                             'acetate': (0.5,
#                                                                         2.0),
#                                                             'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': (0.5,
#                                                                                                                               2.0)},
#                                                'model_file': '/Users/rebekahsheih/PycharmProjects/Rebekahs_Rotation_Project/in_silico_scripts/sbml/bt.xml',
#                                                'name': 'B_thetaiotaomicron',
#                                                'reaction_map': {'Cholate': 'EX_cholate(e)',
#                                                                 'acetate': 'EX_ac(e)',
#                                                                 'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': 'EX_pullulan1200(e)'}},
#                                     'inputs': {'current_update': ['..',
#                                                                   'dFBA '
#                                                                   'Results'],
#                                                'shared_environment': ['..',
#                                                                       'Shared '
#                                                                       'Environment']},
#                                     'interval': 0.1,
#                                     'outputs': {'dfba_update': ['..',
#                                                                 'dFBA Results',
#                                                                 'B_thetaiotaomicron']}},
#              'E_rectale': {'_type': 'process',
#                            'address': 'local:dFBA',
#                            'config': {'bounds': {},
#                                       'changes': {'bounds': {},
#                                                   'gene_knockout': [],
#                                                   'kinetics': {},
#                                                   'reaction_knockout': []},
#                                       'kinetics': {'Cholate': (0.5, 2.0),
#                                                    'acetate': (0.5, 2.0),
#                                                    'butyrate': (0.5, 2.0),
#                                                    'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': (0.5,
#                                                                                                                      2.0)},
#                                       'model_file': '/Users/rebekahsheih/PycharmProjects/Rebekahs_Rotation_Project/in_silico_scripts/sbml/er.xml',
#                                       'name': 'E_rectale',
#                                       'reaction_map': {'Cholate': 'EX_cholate(e)',
#                                                        'acetate': 'EX_ac(e)',
#                                                        'butyrate': 'EX_but(e)',
#                                                        'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': 'EX_pullulan1200(e)'}},
#                            'inputs': {'current_update': ['..', 'dFBA Results'],
#                                       'shared_environment': ['..',
#                                                              'Shared '
#                                                              'Environment']},
#                            'interval': 0.1,
#                            'outputs': {'dfba_update': ['..',
#                                                        'dFBA Results',
#                                                        'E_rectale']}}},
#  'dFBA Results': {'B_thetaiotaomicron': {'B_thetaiotaomicron': 0,
#                                          'Cholate': 0,
#                                          'acetate': 0,
#                                          'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': 0},
#                   'E_rectale': {'Cholate': 0,
#                                 'E_rectale': 0,
#                                 'acetate': 0,
#                                 'butyrate': 0,
#                                 'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': 0}},
#  'update environment': {'_type': 'process',
#                         'address': 'local:UpdateEnvironment',
#                         'config': {},
#                         'inputs': {'shared_environment': ['Shared Environment'],
#                                    'species_updates': ['dFBA Results']},
#                         'outputs': {'counts': ['Shared Environment',
#                                                'counts']}}}

# %%
#Set reaction bounds (constrain bounds here to make it so that the exchange reactions can't take place)
spec['Species']['B_thetaiotaomicron']['config']['bounds'] = {
            "EX_o2(e)": {"lower": -2, "upper": None},
            "DM_atp_c_": {"lower": 1, "upper": 1},
        }
spec['Species']['E_rectale']['config']['bounds'] = {
            "EX_o2(e)": {"lower": -2, "upper": None},
            "DM_atp_c_": {"lower": 1, "upper": 1}
        }

# %%
#set external substrate concentrations
concentrations = {      # zero polysaccharides (pectin and cholate) to stop b theta from growing, limit acetate so that it has to come from keystone species
    'acetate': 0,
    'butyrate': 0,
    'Cholate' : 0, # give cholate so that BT can grow and produce acetate for ER
    'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)' : 10

}
set_concentration(spec, concentrations)

# %%
#set kinetics
kinetics = {
    'acetate': (0.5, 5), # reduce km, increase Vmax
    'butyrate': (0.5, 5),
    'Cholate': (0.5, 5),
    'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)' : (0.5, 5)
}
for species in gut_models.keys():
    set_kinetics(species, spec, kinetics)
pprint(spec)
# Out:
# {'Shared Environment': {'concentrations': {'B_thetaiotaomicron': 0.25,
#                                            'Cholate': 0,
#                                            'E_rectale': 0.25,
#                                            'acetate': 0,
#                                            'butyrate': 0,
#                                            'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': 10},
#                         'counts': {'B_thetaiotaomicron': 0.5,
#                                    'Cholate': 0,
#                                    'E_rectale': 0.5,
#                                    'acetate': 0,
#                                    'butyrate': 0,
#                                    'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': 20},
#                         'volume': 2},
#  'Species': {'B_thetaiotaomicron': {'_type': 'process',
#                                     'address': 'local:dFBA',
#                                     'config': {'bounds': {'DM_atp_c_': {'lower': 1,
#                                                                         'upper': 1},
#                                                           'EX_o2(e)': {'lower': -2,
#                                                                        'upper': None}},
#                                                'changes': {'bounds': {},
#                                                            'gene_knockout': [],
#                                                            'kinetics': {},
#                                                            'reaction_knockout': []},
#                                                'kinetics': {'Cholate': (0.5, 5),
#                                                             'acetate': (0.5, 5),
#                                                             'butyrate': (0.5,
#                                                                          5),
#                                                             'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': (0.5,
#                                                                                                                               5)},
#                                                'model_file': '/Users/rebekahsheih/PycharmProjects/Rebekahs_Rotation_Project/in_silico_scripts/sbml/bt.xml',
#                                                'name': 'B_thetaiotaomicron',
#                                                'reaction_map': {'Cholate': 'EX_cholate(e)',
#                                                                 'acetate': 'EX_ac(e)',
#                                                                 'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': 'EX_pullulan1200(e)'}},
#                                     'inputs': {'current_update': ['..',
#                                                                   'dFBA '
#                                                                   'Results'],
#                                                'shared_environment': ['..',
#                                                                       'Shared '
#                                                                       'Environment']},
#                                     'interval': 0.1,
#                                     'outputs': {'dfba_update': ['..',
#                                                                 'dFBA Results',
#                                                                 'B_thetaiotaomicron']}},
#              'E_rectale': {'_type': 'process',
#                            'address': 'local:dFBA',
#                            'config': {'bounds': {'DM_atp_c_': {'lower': 1,
#                                                                'upper': 1},
#                                                  'EX_o2(e)': {'lower': -2,
#                                                               'upper': None}},
#                                       'changes': {'bounds': {},
#                                                   'gene_knockout': [],
#                                                   'kinetics': {},
#                                                   'reaction_knockout': []},
#                                       'kinetics': {'Cholate': (0.5, 5),
#                                                    'acetate': (0.5, 5),
#                                                    'butyrate': (0.5, 5),
#                                                    'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': (0.5,
#                                                                                                                      5)},
#                                       'model_file': '/Users/rebekahsheih/PycharmProjects/Rebekahs_Rotation_Project/in_silico_scripts/sbml/er.xml',
#                                       'name': 'E_rectale',
#                                       'reaction_map': {'Cholate': 'EX_cholate(e)',
#                                                        'acetate': 'EX_ac(e)',
#                                                        'butyrate': 'EX_but(e)',
#                                                        'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': 'EX_pullulan1200(e)'}},
#                            'inputs': {'current_update': ['..', 'dFBA Results'],
#                                       'shared_environment': ['..',
#                                                              'Shared '
#                                                              'Environment']},
#                            'interval': 0.1,
#                            'outputs': {'dfba_update': ['..',
#                                                        'dFBA Results',
#                                                        'E_rectale']}}},
#  'dFBA Results': {'B_thetaiotaomicron': {'B_thetaiotaomicron': 0,
#                                          'Cholate': 0,
#                                          'acetate': 0,
#                                          'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': 0},
#                   'E_rectale': {'Cholate': 0,
#                                 'E_rectale': 0,
#                                 'acetate': 0,
#                                 'butyrate': 0,
#                                 'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': 0}},
#  'update environment': {'_type': 'process',
#                         'address': 'local:UpdateEnvironment',
#                         'config': {},
#                         'inputs': {'shared_environment': ['Shared Environment'],
#                                    'species_updates': ['dFBA Results']},
#                         'outputs': {'counts': ['Shared Environment',
#                                                'counts']}}}

# %%
#set emitter specs
spec['emitter'] = {
        "_type": "step",
        "address": "local:ram-emitter",
        "config": {
            "emit": {
                "shared_environment": "any",
                "global_time": "any",
            }
        },
        "inputs": {
            "shared_environment": ["Shared Environment"],
            "global_time": ["global_time"]
        }
    }

# %%
#create the core object
core = ProcessTypes()
#register data types
core = register_types(core)
#register all processes and steps
core.register_process('dFBA', dFBA)
core.register_process('UpdateEnvironment', UpdateEnvironment)
core.register_process('StaticConcentration', StaticConcentration)
core.register_process('WaveFunction', WaveFunction)
core.register_process('Injector', Injector)

# %%
# KO all reactions for one species

# %%
sim = Composite({
        "state": spec,
        },
        core=core
    )

# %%
#run simulation
sim.run(20)

# %%
#gather results
results = gather_emitter_results(sim)[('emitter',)]

# %%
#extract time-series data
timepoints = []
for timepoint in results:
    time = timepoint.pop('global_time')
    timepoints.append(time)
env = [timepoint['shared_environment']['concentrations'] for timepoint in results]
env_combined = {}
for d in env:
    for key, value in d.items():
        if key not in env_combined:
            env_combined[key] = []
        env_combined[key].append(value)

# %%
results
# Out:
# [{'shared_environment': {'concentrations': {'Cholate': 0.0,
#     'acetate': 0.0,
#     'butyrate': 0.0,
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': 10.0,
#     'B_thetaiotaomicron': 0.25,
#     'E_rectale': 0.25},
#    'counts': {'Cholate': 0.0,
#     'acetate': 0.0,
#     'butyrate': 0.0,
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': 20.0,
#     'B_thetaiotaomicron': 0.5,
#     'E_rectale': 0.5},
#    'volume': 2.0}},
#  {'shared_environment': {'counts': {'Cholate': 0.0,
#     'acetate': 0.0,
#     'butyrate': 0.0,
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': 20.0,
#     'B_thetaiotaomicron': 0.5,
#     'E_rectale': 0.5},
#    'concentrations': {'Cholate': 0.0,
#     'acetate': 0.0,
#     'butyrate': 0.0,
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': 10.0,
#     'B_thetaiotaomicron': 0.25,
#     'E_rectale': 0.25},
#    'volume': 2.0}},
#  {'shared_environment': {'counts': {'Cholate': np.float64(0.0),
#     'acetate': np.float64(0
},
#    'concentrations': {'Cholate': np.float64(0.0),
#     'acetate': np.float64(1476.3396823601636),
#     'butyrate': np.float64(52032.70217225498),
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': np.float64(0.0),
#     'B_thetaiotaomicron': np.float64(0.25),
#     'E_rectale': np.float64(791.7336206011821)},
#    'volume': 2.0}},
#  {'shared_environment': {'counts': {'Cholate': np.float64(0.0),
#     'acetate': np.float64(2973.3372452563913),
#     'butyrate': np.float64(104368.75587151128),
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': np.float64(0.0),
#     'B_thetaiotaomicron': np.float64(0.5),
#     'E_rectale': np.float64(1586.171245515331)},
#    'concentrations': {'Cholate': np.float64(0.0),
#     'acetate': np.float64(1486.6686226281956),
#     'butyrate': np.float64(52184.37793575564),
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': np.float64(0.0),
#     'B_thetaiotaomicron': np.float64(0.25),
#     'E_rectale': np.float64(793.0856227576655)},
#    'volume': 2.0}},
#  {'shared_environment': {'counts': {'Cholate': np.float64(0.0),
#     'acetate': np.float64(2994.0304021762117),
#     'butyrate': np.float64(104672.62541607306),
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': np.float64(0.0),
#     'B_thetaiotaomicron': np.float64(0.5),
#     'E_rectale': np.float64(1588.8798673152494)},
#    'concentrations': {'Cholate': np.float64(0.0),
#     'acetate': np.float64(1497.0152010881059),
#     'butyrate': np.float64(52336.31270803653),
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': np.float64(0.0),
#     'B_thetaiotaomicron': np.float64(0.25),
#     'E_rectale': np.float64(794.4399336576247)},
#    'volume': 2.0}},
#  {'shared_environment': {'counts': {'Cholate': np.float64(0.0),
#     'acetate': np.float64(3014.7588957194266),
#     'butyrate': np.float64(104977.01386278683),
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': np.float64(0.0),
#     'B_thetaiotaomicron': np.float64(0.5),
#     'E_rectale': np.float64(1591.5931144871606)},
#    'concentrations': {'Cholate': np.float64(0.0),
#     'acetate': np.float64(1507.3794478597133),
#     'butyrate': np.float64(52488.506931393415),
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': np.float64(0.0),
#     'B_thetaiotaomicron': np.float64(0.25),
#     'E_rectale': np.float64(795.7965572435803)},
#    'volume': 2.0}},
#  {'shared_environment': {'counts': {'Cholate': np.float64(0.0),
#     'acetate': np.float64(3035.5227862285424),
#     'butyrate': np.float64(105281.9220977547),
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': np.float64(0.0),
#     'B_thetaiotaomicron': np.float64(0.5),
#     'E_rectale': np.float64(1594.310994929571)},
#    'concentrations': {'Cholate': np.float64(0.0),
#     'acetate': np.float64(1517.7613931142712),
#     'butyrate': np.float64(52640.96104887735),
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': np.float64(0.0),
#     'B_thetaiotaomicron': np.float64(0.25),
#     'E_rectale': np.float64(797.1554974647855)},
#    'volume': 2.0}},
#  {'shared_environment': {'counts': {'Cholate': np.float64(0.0),
#     'acetate': np.float64(3056.3221341491094),
#     'butyrate': np.float64(105587.35100859193),
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': np.float64(0.0),
#     'B_thetaiotaomicron': np.float64(0.5),
#     'E_rectale': np.float64(1597.0335165544748)},
#    'concentrations': {'Cholate': np.float64(0.0),
#     'acetate': np.float64(1528.1610670745547),
#     'butyrate': np.float64(52793.67550429596),
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': np.float64(0.0),
#     'B_thetaiotaomicron': np.float64(0.25),
#     'E_rectale': np.float64(798.5167582772374)},
#    'volume': 2.0}},
#  {'shared_environment': {'counts': {'Cholate': np.float64(0.0),
#     'acetate': np.float64(3077.157000029897),
#     'butyrate': np.float64(105893.3014844295),
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': np.float64(0.0),
#     'B_thetaiotaomicron': np.float64(0.5),
#     'E_rectale': np.float64(1599.7606872873766)},
#    'concentrations': {'Cholate': np.float64(0.0),
#     'acetate': np.float64(1538.5785000149485),
#     'butyrate': np.float64(52946.65074221475),
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': np.float64(0.0),
#     'B_thetaiotaomicron': np.float64(0.25),
#     'E_rectale': np.float64(799.8803436436883)},
#    'volume': 2.0}},
#  {'shared_environment': {'counts': {'Cholate': np.float64(0.0),
#     'acetate': np.float64(3098.0274445230716),
#     'butyrate': np.float64(106199.77441591673),
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': np.float64(0.0),
#     'B_thetaiotaomicron': np.float64(0.5),
#     'E_rectale': np.float64(1602.4925150673155)},
#    'concentrations': {'Cholate': np.float64(0.0),
#     'acetate': np.float64(1549.0137222615358),
#     'butyrate': np.float64(53099.88720795837),
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': np.float64(0.0),
#     'B_thetaiotaomicron': np.float64(0.25),
#     'E_rectale': np.float64(801.2462575336577)},
#    'volume': 2.0}},
#  {'shared_environment': {'counts': {'Cholate': np.float64(0.0),
#     'acetate': np.float64(3118.933528384371),
#     'butyrate': np.float64(106506.77069522387),
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': np.float64(0.0),
#     'B_thetaiotaomicron': np.float64(0.5),
#     'E_rectale': np.float64(1605.2290078468875)},
#    'concentrations': {'Cholate': np.float64(0.0),
#     'acetate': np.float64(1559.4667641921856),
#     'butyrate': np.float64(53253.38534761193),
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': np.float64(0.0),
#     'B_thetaiotaomicron': np.float64(0.25),
#     'E_rectale': np.float64(802.6145039234437)},
#    'volume': 2.0}},
#  {'shared_environment': {'counts': {'Cholate': np.float64(0.0),
#     'acetate': np.float64(3139.8753124732834),
#     'butyrate': np.float64(106814.29121604463),
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': np.float64(0.0),
#     'B_thetaiotaomicron': np.float64(0.5),
#     'E_rectale': np.float64(1607.9701735922688)},
#    'concentrations': {'Cholate': np.float64(0.0),
#     'acetate': np.float64(1569.9376562366417),
#     'butyrate': np.float64(53407.145608022314),
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': np.float64(0.0),
#     'B_thetaiotaomicron': np.float64(0.25),
#     'E_rectale': np.float64(803.9850867961344)},
#    'volume': 2.0}},
#  {'shared_environment': {'counts': {'Cholate': np.float64(0.0),
#     'acetate': np.float64(3160.8528577532225),
#     'butyrate': np.float64(107122.33687359886),
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': np.float64(0.0),
#     'B_thetaiotaomicron': np.float64(0.5),
#     'E_rectale': np.float64(1610.7160202832392)},
#    'concentrations': {'Cholate': np.float64(0.0),
#     'acetate': np.float64(1580.4264288766112),
#     'butyrate': np.float64(53561.16843679943),
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': np.float64(0.0),
#     'B_thetaiotaomicron': np.float64(0.25),
#     'E_rectale': np.float64(805.3580101416196)},
#    'volume': 2.0}},
#  {'shared_environment': {'counts': {'Cholate': np.float64(0.0),
#     'acetate': np.float64(3181.866225291707),
#     'butyrate': np.float64(107430.90856463516),
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': np.float64(0.0),
#     'B_thetaiotaomicron': np.float64(0.5),
#     'E_rectale': np.float64(1613.466555913205)},
#    'concentrations': {'Cholate': np.float64(0.0),
#     'acetate': np.float64(1590.9331126458535),
#     'butyrate': np.float64(53715.45428231758),
#     'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)': np.float64(0.0),
#     'B_thetaiotaomicron': np.float64(0.25),
#     'E_rectale': np.float64(806.7332779566025)},
#    'volume': 2.0}}]

# %%
#plot results for biomass
fig, ax = plt.subplots(dpi=300)
for key, value in env_combined.items():
    if key not in ['acetate', 'butyrate', 'Cholate', 'pullulan (n=1200 repeat units, alpha-1,4 and alph-1,6 bounds)']:
        ax.plot(timepoints, env_combined[key], label=key)
        ax.set_yscale('log')
plt.ylim(0, 10e3)
plt.xlabel('Time (h)')
plt.ylabel('Biomass (gDW)')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/83/2fn1zt090m956h7gkwysmm980000gn/T/ipykernel_12097/2007386906.py:7: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(0, 10e3)

# %%
#plot substrates
fig, ax = plt.subplots(dpi=300)
for key, value in env_combined.items():
    if key in ['acetate', 'Cholate', 'butyrate']:
        ax.plot(timepoints, env_combined[key], label=key)
        ax.set_yscale('log')
plt.ylim(1, 10e4)
plt.xlabel('Time (h)')
plt.ylabel('Substrate Concentration (mM)')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/83/2fn1zt090m956h7gkwysmm980000gn/T/ipykernel_12097/115205709.py:6: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax.set_yscale('log')
